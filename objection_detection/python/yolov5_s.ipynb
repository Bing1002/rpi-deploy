# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load the YOLOv5s model from PyTorch Hub
model = torch.hub.load('ultralytics/yolov5:v6.2', 'yolov5s', 
                       pretrained=True, device=device, verbose=False)

# Set the model to evaluation mode
model.eval()
# Out:
# YOLOv5 🚀 2024-11-26 Python-3.11.2 torch-2.5.1 CPU
#
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
# Example image URL or path
img = '../../data/bus.jpg'  # Replace with your image path or URL

# Perform inference
results = model(img)

# Print results (bounding boxes, confidence scores, etc.)
print(results.pandas().xyxy)  # Print results as a pandas DataFrame
# Out:
# /home/bing/.cache/torch/hub/ultralytics_yolov5_v6.2/models/common.py:630: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# [         xmin        ymin        xmax        ymax  confidence  class    name
# 0  671.787842  395.372040  810.000000  878.361328    0.896172      0  person
# 1  220.657059  408.141022  346.167389  867.381165    0.870248      0  person
# 2   49.250828  389.990570  248.078262  912.458679    0.851563      0  person
# 3   12.650714  223.378433  809.707275  788.516357    0.849334      5     bus
# 4    0.045402  552.411377   67.882339  875.374756    0.534941      0  person]
